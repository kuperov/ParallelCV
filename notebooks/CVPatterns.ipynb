# %% [markdown]
# # CV patterns

# %%
from jax import numpy as jnp, lax,random
import jax
from ploo.cv import *
import matplotlib.pyplot as plt

# %%
loo = LOO(shape=50)
plt.matshow(loo.summary_array());

# %%
lfo = LFO(shape=50, margin=15)
plt.matshow(lfo.summary_array());

# %%
kf = KFold(shape=50, k=10, rng_key=random.PRNGKey(seed=42))
plt.matshow(kf.summary_array());
